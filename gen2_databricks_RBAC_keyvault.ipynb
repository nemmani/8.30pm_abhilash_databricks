# %%
dbutils.help()

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope="testconnection")

# %%
dbutils.secrets.get(scope="testconnection", key="appid")
dbutils.secrets.get(scope="testconnection", key="apppwd")

# %%
spark.conf.set(
    "fs.azure.account.auth.type.strageacvaultrabac.dfs.core.windows.net",
    "OAuth"
)

spark.conf.set(
    "fs.azure.account.oauth.provider.type.strageacvaultrabac.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)

spark.conf.set(
    "fs.azure.account.oauth2.client.id.strageacvaultrabac.dfs.core.windows.net",
    dbutils.secrets.get(scope="testconnection", key="appid")
)

spark.conf.set(
    "fs.azure.account.oauth2.client.secret.strageacvaultrabac.dfs.core.windows.net",
    dbutils.secrets.get(scope="testconnection", key="apppwd")
)

spark.conf.set(
    "fs.azure.account.oauth2.client.endpoint.strageacvaultrabac.dfs.core.windows.net",
    "https://login.microsoftonline.com/5faad092-ee54-4d69-b6bf-542e30440bd7/oauth2/v2.0/token"
)

# %%
df = spark.read.format("csv").option("header","true").option("inferSchema","true").load(
    "abfss://bronze@strageacvaultrabac.dfs.core.windows.net/"
)
display(df)
