# %%
# %sql
create table employees(
    emp_id int,
    emp_name varchar(50),
    department varchar(50),
    salary int,
    age int,
    city varchar(50),
    exeperice int 
)

# %%
# %sql
insert into employees values
(101,'ravi','IT',60000,28,'hyderabad',5),
(102,'sai','HR',50000,25,'hyderabad',3),
(103,'suresh','IT',70000,30,'bangalore',7),
(104,'ramesh','IT',80000,35,'bangalore',10),
(105,'kumar','HR',55000,28,'bangalore',4),
(106,'santhosh','IT',65000,32,'bangalore',6),
(107,'sudharsan','IT',75000,38,'bangalore',8),
(108,'santhosh','IT',65000,32,'bangalore',6)

# %%
# arithmetic operations
# + addition
# - sub
# * multiplication
# / division
# % modulo

# %%
# %sql
select * from employees

# %%
# %sql
select emp_name, salary, salary +5000 as increase_salary from employees

# %%
# %sql
select emp_name, salary, salary - 5000 as reduced_salary from employees

# %%
# %sql
select emp_name, salary, salary * 12 as annual_salary from employees

# %%
# %sql
select emp_name, salary, salary / 12 as monthly_salary from employees

# %%
# %sql
select emp_id, emp_name, age % 2 as remainder from employees

# %%
# comparision operator 
# = Equal
# <> or != not equal
# > greater tan
# < less than
# >= greater than or equal
# <= less than or equal

# %%
# %sql
select * from employees

# %%
# %sql
select * from employees where department = 'IT'

# %%
# %sql
select * from employees where department <> 'IT'

# %%
# %sql
select * from employees where salary > 60000

# %%
# %sql
select * from employees where age < 30

# %%
# %sql
select * from employees where salary >= 70000

# %%
# %sql
select * from employees where age <= 30

# %%
# logical operators
# and both conditions must be true
# or either condition must be true
# not reverse the condition

# %%
# %sql
select * from employees

# %%
# %sql
select * from employees where department = 'IT' AND salary > 60000

# %%
# %sql
select * from employees where department = 'IT' or department = 'HR'

# %%
# %sql
select * from employees where not department = 'IT'

# %%
# %sql
select * from employees

# %%
# %sql
select * from employees where salary between 50000 and 70000

# %%
# %sql
-- in operator
select * from employees where department in ('IT','HR')

# %%
# %sql
-- in operator
select * from employees where department not in ('IT','HR')

# %%
# %sql
select * from employees

# %%
# %sql
--like operator
select * from employees where emp_name like '%h'

# %%
# %sql
select * from employees

# %%
# %sql
-- assignment operators
update employees set salary=65000 where emp_id=101
